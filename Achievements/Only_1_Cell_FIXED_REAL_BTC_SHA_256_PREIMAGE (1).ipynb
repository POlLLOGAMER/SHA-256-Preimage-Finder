# %%
#@title ⛏️ BITCOIN 100% (CORREGIDO FINAL): SHA256d(80B) CNF universal + SAT phase-hints + PoW por target bits
# !pip install python-sat -q

import hashlib
import re
import time
from pysat.solvers import Solver as PySolver

# ============================================================
# Utils Bitcoin
# ============================================================

def sha256d(b: bytes) -> bytes:
    return hashlib.sha256(hashlib.sha256(b).digest()).digest()

def bits_compact_to_target_int(bits32: int) -> int:
    exp = (bits32 >> 24) & 0xff
    mant = bits32 & 0x007fffff  # ignora sign bit como Bitcoin
    if mant == 0:
        return 0
    if exp <= 3:
        return mant >> (8 * (3 - exp))
    return mant << (8 * (exp - 3))

def target_int_to_hex_be(target_int: int) -> str:
    return target_int.to_bytes(32, 'big').hex()

def hash_display_hex(hash_bytes: bytes) -> str:
    return hash_bytes[::-1].hex()

def count_leading_zero_bits_display(hash_bytes: bytes) -> int:
    b = hash_bytes[::-1]
    count = 0
    for byte in b:
        if byte == 0:
            count += 8
        else:
            for i in range(7, -1, -1):
                if ((byte >> i) & 1) == 0:
                    count += 1
                else:
                    return count
            return count
    return count

# ============================================================
# CNF Builder: SHA256d(header80) UNIVERSAL (FIX PADDING)
#  - bits in words: LSB-first (bit0 = 2^0)
#  - header80 bytes reconstructed as word.to_bytes(4,'big')
# ============================================================

class CNFBuilderSHA256d80:
    def __init__(self):
        self.var_count = 0
        self.clauses = []
        self.var_map = {}

        self.K = [
            0x428a2f98, 0x71374491, 0xb5c0fbcf, 0xe9b5dba5, 0x3956c25b, 0x59f111f1, 0x923f82a4, 0xab1c5ed5,
            0xd807aa98, 0x12835b01, 0x243185be, 0x550c7dc3, 0x72be5d74, 0x80deb1fe, 0x9bdc06a7, 0xc19bf174,
            0xe49b69c1, 0xefbe4786, 0x0fc19dc6, 0x240ca1cc, 0x2de92c6f, 0x4a7484aa, 0x5cb0a9dc, 0x76f988da,
            0x983e5152, 0xa831c66d, 0xb00327c8, 0xbf597fc7, 0xc6e00bf3, 0xd5a79147, 0x06ca6351, 0x14292967,
            0x27b70a85, 0x2e1b2138, 0x4d2c6dfc, 0x53380d13, 0x650a7354, 0x766a0abb, 0x81c2c92e, 0x92722c85,
            0xa2bfe8a1, 0xa81a664b, 0xc24b8b70, 0xc76c51a3, 0xd192e819, 0xd6990624, 0xf40e3585, 0x106aa070,
            0x19a4c116, 0x1e376c08, 0x2748774c, 0x34b0bcb5, 0x391c0cb3, 0x4ed8aa4a, 0x5b9cca4f, 0x682e6ff3,
            0x748f82ee, 0x78a5636f, 0x84c87814, 0x8cc70208, 0x90befffa, 0xa4506ceb, 0xbef9a3f7, 0xc67178f2
        ]
        self.H_init = [
            0x6a09e667, 0xbb67ae85, 0x3c6ef372, 0xa54ff53a,
            0x510e527f, 0x9b05688c, 0x1f83d9ab, 0x5be0cd19
        ]

    def new_var(self, name=None):
        self.var_count += 1
        if name:
            self.var_map[name] = self.var_count
        return self.var_count

    def add_clause(self, lits):
        self.clauses.append(lits)

    def gate_xor(self, a, b):
        c = self.new_var()
        self.add_clause([-a, -b, -c])
        self.add_clause([a, b, -c])
        self.add_clause([a, -b, c])
        self.add_clause([-a, b, c])
        return c

    def gate_and(self, a, b):
        c = self.new_var()
        self.add_clause([-a, -b, c])
        self.add_clause([a, -c])
        self.add_clause([b, -c])
        return c

    def gate_maj(self, a, b, c):
        out = self.new_var()
        self.add_clause([-a, -b, out])
        self.add_clause([-a, -c, out])
        self.add_clause([-b, -c, out])
        self.add_clause([a, b, -out])
        self.add_clause([a, c, -out])
        self.add_clause([b, c, -out])
        return out

    def gate_ch(self, e, f, g):
        out = self.new_var()
        self.add_clause([-e, -f, out])
        self.add_clause([-e, f, -out])
        self.add_clause([e, -g, out])
        self.add_clause([e, g, -out])
        return out

    def const_word(self, val):
        bits = []
        for i in range(32):
            bit_val = (val >> i) & 1
            v = self.new_var()
            self.add_clause([v] if bit_val else [-v])
            bits.append(v)
        return bits  # LSB-first

    def rot_right(self, w, n):
        return w[n:] + w[:n]

    def shift_right(self, w, n):
        zeros = []
        for _ in range(n):
            z = self.new_var()
            self.add_clause([-z])
            zeros.append(z)
        return w[n:] + zeros

    def xor_word(self, w1, w2):
        return [self.gate_xor(a, b) for a, b in zip(w1, w2)]

    def add_word(self, w1, w2):
        result = []
        carry = None
        for i in range(32):
            a = w1[i]
            b = w2[i]
            if carry is None:
                s = self.gate_xor(a, b)
                c_out = self.gate_and(a, b)
            else:
                tmp = self.gate_xor(a, b)
                s = self.gate_xor(tmp, carry)
                ab = self.gate_and(a, b)
                cin_xor = self.gate_and(carry, tmp)
                c_out = self.new_var()
                self.add_clause([-ab, c_out])
                self.add_clause([-cin_xor, c_out])
                self.add_clause([ab, cin_xor, -c_out])
            result.append(s)
            carry = c_out
        return result

    def sigma0(self, w):
        return self.xor_word(self.xor_word(self.rot_right(w, 7), self.rot_right(w, 18)),
                             self.shift_right(w, 3))

    def sigma1(self, w):
        return self.xor_word(self.xor_word(self.rot_right(w, 17), self.rot_right(w, 19)),
                             self.shift_right(w, 10))

    def Sigma0(self, w):
        return self.xor_word(self.xor_word(self.rot_right(w, 2), self.rot_right(w, 13)),
                             self.rot_right(w, 22))

    def Sigma1(self, w):
        return self.xor_word(self.xor_word(self.rot_right(w, 6), self.rot_right(w, 11)),
                             self.rot_right(w, 25))

    def Maj_word(self, x, y, z):
        return [self.gate_maj(a, b, c) for a, b, c in zip(x, y, z)]

    def Ch_word(self, x, y, z):
        return [self.gate_ch(a, b, c) for a, b, c in zip(x, y, z)]

    def expand_W(self, M16):
        W = [None] * 64
        for i in range(16):
            W[i] = M16[i]
        for i in range(16, 64):
            s1 = self.sigma1(W[i-2])
            s0 = self.sigma0(W[i-15])
            t1 = self.add_word(s1, W[i-7])
            t2 = self.add_word(s0, W[i-16])
            W[i] = self.add_word(t1, t2)
        return W

    def compress_block(self, M16, H_state):
        W = self.expand_W(M16)
        a, b, c, d, e, f, g, h = H_state

        for i in range(64):
            S1_e = self.Sigma1(e)
            ch = self.Ch_word(e, f, g)
            ki = self.const_word(self.K[i])

            sum1 = self.add_word(h, S1_e)
            sum2 = self.add_word(ch, ki)
            sum3 = self.add_word(sum1, sum2)
            T1 = self.add_word(sum3, W[i])

            S0_a = self.Sigma0(a)
            maj = self.Maj_word(a, b, c)
            T2 = self.add_word(S0_a, maj)

            h = g
            g = f
            f = e
            e = self.add_word(d, T1)
            d = c
            c = b
            b = a
            a = self.add_word(T1, T2)

        final_work = [a, b, c, d, e, f, g, h]
        new_H = []
        for i in range(8):
            new_H.append(self.add_word(H_state[i], final_work[i]))
        return new_H

    def build_sha256d_header80(self):
        # header80 = 20 words = 80 bytes
        hdr_words = []
        for wi in range(20):
            wbits = []
            for bi in range(32):
                v = self.new_var(f"hdr_w{wi}_b{bi}")
                wbits.append(v)
            hdr_words.append(wbits)

        # -------- SHA256(header80) = 2 blocks --------
        block1 = hdr_words[0:16]

        # block2 words:
        # w0..w3 = hdr16..hdr19
        # w4 = 0x80000000
        # w5..w13 = 0
        # w14 = 0
        # w15 = 0x00000280 (len 640 bits)
        block2 = []
        block2.extend(hdr_words[16:20])                  # w0..w3
        block2.append(self.const_word(0x80000000))       # w4
        for _ in range(5, 14):                           # w5..w13 (9 words)  <-- FIX
            block2.append(self.const_word(0))
        block2.append(self.const_word(0))                # w14
        block2.append(self.const_word(0x00000280))       # w15
        assert len(block2) == 16

        H0 = [self.const_word(x) for x in self.H_init]
        H1 = self.compress_block(block1, H0)
        H2 = self.compress_block(block2, H1)             # digest1 (8 words)

        # -------- SHA256(digest1) = 1 block --------
        # block3 words:
        # w0..w7 = digest1
        # w8 = 0x80000000
        # w9..w13 = 0
        # w14 = 0
        # w15 = 0x00000100 (len 256 bits)
        block3 = []
        block3.extend(H2)                                # w0..w7
        block3.append(self.const_word(0x80000000))       # w8
        for _ in range(9, 14):                           # w9..w13 (5 words)  <-- FIX
            block3.append(self.const_word(0))
        block3.append(self.const_word(0))                # w14
        block3.append(self.const_word(0x00000100))       # w15
        assert len(block3) == 16

        H0b = [self.const_word(x) for x in self.H_init]
        H3 = self.compress_block(block3, H0b)            # final digest (8 words)

        for wi in range(8):
            for bi, var in enumerate(H3[wi]):
                self.var_map[f"hash_w{wi}_b{bi}"] = var

        for bi, var in enumerate(hdr_words[19]):
            self.var_map[f"nonce_b{bi}"] = var

        return hdr_words, H3

    def save_dimacs(self, filename):
        with open(filename, 'w') as f:
            f.write(f"p cnf {self.var_count} {len(self.clauses)}\n")
            for clause in self.clauses:
                f.write(" ".join(map(str, clause)) + " 0\n")
        with open(filename + ".map", "w") as f:
            for k, v in self.var_map.items():
                f.write(f"{k}:{v}\n")

# ============================================================
# SAT with "heurística 100 adaptada" = phase hints
# ============================================================

def parse_cnf_and_build_phases(cnf_text: str):
    nvars = 0
    clauses = []
    clause = []
    pos = None
    neg = None
    forced = {}

    for line in cnf_text.splitlines():
        line = line.strip()
        if not line or line[0] in 'c%':
            continue
        if line.startswith('p cnf'):
            parts = line.split()
            nvars = int(parts[2])
            pos = [0.0] * (nvars + 1)
            neg = [0.0] * (nvars + 1)
            continue

        for tok in line.split():
            try:
                lit = int(tok)
            except:
                continue
            if lit == 0:
                if clause:
                    clauses.append(clause)
                    w = 1.0 / (len(clause) ** 1.5)
                    for L in clause:
                        v = abs(L)
                        if L > 0:
                            pos[v] += w
                        else:
                            neg[v] += w
                    if len(clause) == 1:
                        L = clause[0]
                        forced[abs(L)] = (L > 0)
                    clause = []
            else:
                clause.append(lit)

    if clause:
        clauses.append(clause)
        w = 1.0 / (len(clause) ** 1.5)
        for L in clause:
            v = abs(L)
            if L > 0:
                pos[v] += w
            else:
                neg[v] += w
        if len(clause) == 1:
            L = clause[0]
            forced[abs(L)] = (L > 0)

    phases = []
    for v in range(1, nvars + 1):
        if v in forced:
            phases.append(v if forced[v] else -v)
        else:
            if pos[v] > 0 and neg[v] == 0:
                phases.append(v)
            elif neg[v] > 0 and pos[v] == 0:
                phases.append(-v)
            else:
                phases.append(v if pos[v] >= neg[v] else -v)

    return nvars, clauses, phases

def solve_with_pysat_phases(nvars, clauses, phases, solver_name='g3'):
    s = PySolver(name=solver_name)
    for c in clauses:
        s.add_clause(c)

    used_phases = False
    try:
        s.set_phases(phases)
        used_phases = True
    except Exception:
        pass

    t0 = time.time()
    ok = s.solve()
    t1 = time.time()

    if not ok:
        s.delete()
        return "UNSAT", None, (t1 - t0), used_phases

    model = s.get_model()
    s.delete()
    asig = {abs(lit): (lit > 0) for lit in model}
    return "SAT", asig, (t1 - t0), used_phases

# ============================================================
# DIMACS writer/reader (FIXED)
# ============================================================

def save_dimacs_result(base, asig_final, nvars, chunk=15):
    out = f"{base}_DIMACS_resultado.txt"
    lines = ["s SAT"]
    lits = []
    for v in range(1, nvars + 1):
        val = asig_final.get(v, True)
        lits.append(str(v if val else -v))
    for i in range(0, len(lits), chunk):
        chunk_lits = lits[i:i+chunk]
        lines.append("v " + " ".join(chunk_lits) + " 0")
    text = "\n".join(lines)
    with open(out, "w") as f:
        f.write(text)
    return out, text

class BitcoinSATModel:
    def __init__(self, map_text: str, dimacs_result_text: str):
        self.var_by_name = {}
        for line in map_text.splitlines():
            if ':' not in line:
                continue
            k, v = line.strip().split(':', 1)
            try:
                v = int(v)
            except:
                continue
            self.var_by_name[k] = v

        self.assign = {}
        for line in dimacs_result_text.splitlines():
            line = line.strip()
            if not line.startswith("v "):
                continue
            parts = line.split()
            lits = parts[1:]
            if lits and lits[-1] == "0":
                lits = lits[:-1]
            for lit_str in lits:
                try:
                    lit = int(lit_str)
                except:
                    continue
                self.assign[abs(lit)] = (lit > 0)

    def _word_from_bits(self, prefix: str, wi: int) -> int:
        val = 0
        for bi in range(32):
            var = self.var_by_name.get(f"{prefix}{wi}_b{bi}")
            if var and self.assign.get(var, False):
                val |= (1 << bi)
        return val

    def get_header80_bytes(self) -> bytes:
        b = bytearray()
        for wi in range(20):
            w = self._word_from_bits("hdr_w", wi)
            b.extend(w.to_bytes(4, 'big'))
        return bytes(b)

    def get_hash_bytes(self) -> bytes:
        b = bytearray()
        for wi in range(8):
            w = self._word_from_bits("hash_w", wi)
            b.extend(w.to_bytes(4, 'big'))
        return bytes(b)

# ============================================================
# Mining loop (Bitcoin PoW real)
# ============================================================

def mine_pow_by_bits(header80_base: bytes, bits_hex: str, max_seconds=10.0, report_every=200000):
    bits_hex = bits_hex.lower().strip()
    if not re.fullmatch(r"[0-9a-f]{8}", bits_hex):
        raise ValueError("bits_hex debe ser 8 hex (ej: 1d00ffff)")

    bits32 = int(bits_hex, 16)
    exp = (bits32 >> 24) & 0xff
    mant = bits32 & 0x007fffff
    if mant == 0:
        raise ValueError("bits compact inválido (mantisa=0). NO uses 1d800000. Usa 1d00ffff o 207fffff.")

    target = bits_compact_to_target_int(bits32)
    target_hex = target_int_to_hex_be(target)

    print("\n" + "="*70)
    print("⛏️  MINING (Bitcoin real): SHA256d(header80) <= target(bits)")
    print("="*70)
    print("bits:", bits_hex, "target_be:", target_hex)

    header = bytearray(header80_base)
    start_nonce = int.from_bytes(header[76:80], 'little', signed=False)
    print("Nonce inicial (LE):", start_nonce)

    t0 = time.time()
    tries = 0
    best_zeros = -1
    best_hash = None
    best_header = None

    nonce = start_nonce
    while True:
        header[76:80] = nonce.to_bytes(4, 'little', signed=False)
        h = sha256d(bytes(header))
        h_int_le = int.from_bytes(h, 'little')
        tries += 1

        zeros = count_leading_zero_bits_display(h)
        if zeros > best_zeros:
            best_zeros = zeros
            best_hash = h
            best_header = bytes(header)

        if h_int_le <= target:
            t1 = time.time()
            print("\n🎉 FOUND POW!")
            print("Tiempo:", f"{t1 - t0:.3f}s", "intentos:", tries)
            print("Header80:", bytes(header).hex())
            print("Hash raw:", h.hex())
            print("Hash display:", hash_display_hex(h))
            print("Leading zeros (display):", zeros)
            return bytes(header), h

        if tries % report_every == 0:
            elapsed = time.time() - t0
            print(f"tries={tries} elapsed={elapsed:.1f}s bestZeros={best_zeros} bestHashDisplay={hash_display_hex(best_hash)[:24]}...")
            if elapsed >= max_seconds:
                print("\n⏱️ Tiempo límite alcanzado.")
                print("Mejor hasta ahora:")
                print("bestZeros:", best_zeros)
                print("bestHeader80:", best_header.hex())
                print("bestHash display:", hash_display_hex(best_hash))
                return None, None

        nonce = (nonce + 1) & 0xffffffff

# ============================================================
# PIPELINE RUN
# ============================================================

print("="*70)
print("  ⛏️ BITCOIN 100% PIPELINE (CORREGIDO FINAL)")
print("  CNF universal SHA256d(80B) + PySAT phase-hints + mining por target bits")
print("="*70)

# Build CNF
t_build0 = time.time()
builder = CNFBuilderSHA256d80()
builder.build_sha256d_header80()
builder.save_dimacs("bitcoin_sha256d_80B.cnf")
t_build1 = time.time()
print(f"\nCNF generado: vars={builder.var_count}, clauses={len(builder.clauses)} | build={t_build1-t_build0:.2f}s")

with open("bitcoin_sha256d_80B.cnf", "r") as f:
    cnf_text = f.read()
with open("bitcoin_sha256d_80B.cnf.map", "r") as f:
    map_text = f.read()

# Parse + phases
print("\n[1/3] Parse CNF + construir phase-hints...")
t_p0 = time.time()
nvars, clauses, phases = parse_cnf_and_build_phases(cnf_text)
t_p1 = time.time()
print(f"    nvars={nvars} clauses={len(clauses)} phases={len(phases)} time={t_p1-t_p0:.2f}s")

# Solve
print("\n[2/3] PySAT solve con phase-hints...")
res, asig, t_solve, used_phases = solve_with_pysat_phases(nvars, clauses, phases, solver_name='g3')
print(f"    res={res} solve_time={t_solve:.2f}s used_phases={used_phases}")
if res != "SAT":
    raise RuntimeError("UNSAT (inesperado en CNF universal).")

# Save DIMACS
print("\n[3/3] Guardando modelo DIMACS (FIXED)...")
out_file, dimacs_text = save_dimacs_result("bitcoin_sha256d_80B", asig, nvars, chunk=15)
print("    ->", out_file)

# Verify model
model = BitcoinSATModel(map_text, dimacs_text)
header80 = model.get_header80_bytes()
hash_cnf = model.get_hash_bytes()
hash_real = sha256d(header80)

print("\n" + "="*70)
print("✅ Verificación SHA256d(header80) del modelo SAT")
print("="*70)
print("Header80:", header80.hex())
print("Hash CNF :", hash_cnf.hex())
print("Hash real:", hash_real.hex())
print("Hash display:", hash_display_hex(hash_real))
print("Coinciden:", hash_cnf == hash_real)

if hash_cnf != hash_real:
    print("\n❌ Si esto sigue false, algo más está mal (pero con este fix normalmente queda True).")

# Mining interactive
print("\n" + "="*70)
print("⛏️ MINERÍA REAL por bits compact (Bitcoin)")
print("Ejemplos:")
print("  - Genesis bits: 1d00ffff")
print("  - Fácil: 207fffff")
print("="*70)

while True:
    bits_hex = input("\nBITS compact (8 hex) o 'q': ").strip()
    if bits_hex.lower() == 'q':
        break
    max_s = input("max_seconds (ej 5, 10, 60, 500): ").strip()
    try:
        max_seconds = float(max_s)
    except:
        max_seconds = 10.0

    try:
        found_header, found_hash = mine_pow_by_bits(header80, bits_hex, max_seconds=max_seconds, report_every=200000)
    except Exception as e:
        print("Error:", e)
        continue

    if found_header is not None:
        print("\n✅ SOLUCIÓN PoW encontrada")
        print("Header80:", found_header.hex())
        print("Hash display:", hash_display_hex(found_hash))
        print("Leading zeros (display):", count_leading_zero_bits_display(found_hash))
    else:
        print("\n⚠️ No encontrado en este tiempo. Sube max_seconds o baja dificultad.")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 49.6 MB/s eta 0:00:00
# ======================================================================
#   ⛏️ BITCOIN 100% PIPELINE (CORREGIDO FINAL)
#   CNF universal SHA256d(80B) + PySAT phase-hints + mining por target bits
# ======================================================================
#
# CNF generado: vars=347704, clauses=1203840 | build=1.25s
#
# [1/3] Parse CNF + construir phase-hints...
#     nvars=347704 clauses=1203840 phases=347704 time=1.98s
#
# [2/3] PySAT solve con phase-hints...
#     res=SAT solve_time=16.16s used_phases=True
#
# [3/3] Guardando modelo DIMACS (FIXED)...
#     -> bitcoin_sha256d_80B_DIMACS_resultado.txt
#
# ======================================================================
# ✅ Verificación SHA256d(header80) del modelo SAT
# ======================================================================
# Header80: 0d5452657c5f22e0d240f335aaf33db322a1a72431770f37d31b9f42420c2a09d49c87327e4098a86b77e4b999ce5f0b7e0cf488e80dc2b0361bacddf650efdd80716c18817295a29164e8640fa4ca54
# Hash CNF : f4008cb5bcdcf764c167ca59179e128b4fbd26432e26f9d612451f70d12cf5ba
# Hash real: f4008cb5bcdcf764c167ca59179e128b4fbd26432e26f9d612451f70d12cf5ba
# Hash display: baf52cd1701f4512d6f9262e4326bd4f8b129e1759ca67c164f7dcbcb58c00f4
# Coinciden: True
#
# ======================================================================
# ⛏️ MINERÍA REAL por bits compact (Bitcoin)
# Ejemplos:
#   - Genesis bits: 1d00ffff
#   - Fácil: 207fffff
# ======================================================================
#
# BITS compact (8 hex) o 'q': 1d00ffff
# max_seconds (ej 5, 10, 60, 500): 500
#
# ======================================================================
# ⛏️  MINING (Bitcoin real): SHA256d(header80) <= target(bits)
# ======================================================================
# bits: 1d00ffff target_be: 00000000ffff0000000000000000000000000000000000000000000000000000
# Nonce inicial (LE): 1422566415
# tries=200000 elapsed=0.4s bestZeros=17 bestHashDisplay=000063b23d977241c07c5bbd...
# tries=400000 elapsed=0.8s bestZeros=17 bestHashDisplay=000063b23d977241c07c5bbd...
# tries=600000 elapsed=1.2s bestZeros=22 bestHashDisplay=0000026f158d76abfea31295...
# tries=800000 elapsed=1.6s bestZeros=22 bestHashDisplay=0000026f158d76abfea31295...
# tries=1000000 elapsed=1.9s bestZeros=22 bestHashDisplay=0000026f158d76abfea31295...
# tries=1200000 elapsed=2.3s bestZeros=22 bestHashDisplay=0000026f158d76abfea31295...
# tries=1400000 elapsed=2.7s bestZeros=22 bestHashDisplay=0000026f158d76abfea31295...
# tries=1600000 elapsed=3.1s bestZeros=22 bestHashDisplay=0000026f158d76abfea31295...
# tries=1800000 elapsed=3.5s bestZeros=22 bestHashDisplay=0000026f158d76abfea31295...
# tries=2000000 elapsed=3.9s bestZeros=22 bestHashDisplay=0000026f158d76abfea31295...
# tries=2200000 elapsed=4.3s bestZeros=22 bestHashDisplay=0000026f158d76abfea31295...
# tries=2400000 elapsed=4.7s bestZeros=22 bestHashDisplay=0000026f158d76abfea31295...
# tries=2600000 elapsed=5.1s bestZeros=22 bestHashDisplay=0000026f158d76abfea31295...
# tries=2800000 elapsed=5.5s bestZeros=22 bestHashDisplay=0000026f158d76abfea31295...
# tries=3000000 elapsed=5.9s bestZeros=22 bestHashDisplay=0000026f158d76abfea31295...
# tries=3200000 elapsed=6.3s bestZeros=22 bestHashDisplay=0000026f158d76abfea31295...
# tries=3400000 elapsed=6.7s bestZeros=22 bestHashDisplay=0000026f158d76abfea31295...
# tries=3600000 elapsed=7.0s bestZeros=22 bestHashDisplay=0000026f158d76abfea31295...
# tries=3800000 elapsed=7.4s bestZeros=22 bestHashDisplay=0000026f158d76abfea31295...
# tries=4000000 elapsed=7.8s bestZeros=22 bestHashDisplay=0000026f158d76abfea31295...
# tries=4200000 elapsed=8.2s bestZeros=22 bestHashDisplay=0000026f158d76abfea31295...
# tries=4400000 elapsed=8.6s bestZeros=22 bestHashDisplay=0000026f158d76abfea31295...
# tries=4600000 elapsed=9.0s bestZeros=22 bestHashDisplay=0000026f158d76abfea31295...
# tries=4800000 elapsed=9.4s bestZeros=22 bestHashDisplay=0000026f158d76abfea31295...
# tries=5000000 elapsed=9.8s bestZeros=22 bestHashDisplay=0000026f158d76abfea31295...
# tries=5200000 elapsed=10.2s bestZeros=22 bestHashDisplay=0000026f158d76abfea31295...
# tries=5400000 elapsed=10.6s bestZeros=22 bestHashDisplay=0000026f158d76abfea31295...
# tries=5600000 elapsed=11.0s bestZeros=22 bestHashDisplay=0000026f158d76abfea31295...
# tries=5800000 elapsed=11.3s bestZeros=22 bestHashDisplay=0000026f158d76abfea31295...
# tries=6000000 elapsed=11.7s bestZeros=22 bestHashDisplay=0000026f158d76abfea31295...
# tries=6200000 elapsed=12.1s bestZeros=22 bestHashDisplay=0000026f158d76abfea31295...
# tries=6400000 elapsed=12.5s bestZeros=22 bestHashDisplay=0000026f158d76abfea31295...
# tries=6600000 elapsed=12.9s bestZeros=22 bestHashDisplay=0000026f158d76abfea31295...
# tries=6800000 elapsed=13.3s bestZeros=22 bestHashDisplay=0000026f158d76abfea31295...
# tries=7000000 elapsed=13.7s bestZeros=22 bestHashDisplay=0000026f158d76abfea31295...
# tries=7200000 elapsed=14.1s bestZeros=22 bestHashDisplay=0000026f158d76abfea31295...
# tries=7400000 elapsed=14.5s bestZeros=22 bestHashDisplay=0000026f158d76abfea31295...
# tries=7600000 elapsed=14.9s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=7800000 elapsed=15.3s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=8000000 elapsed=15.7s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=8200000 elapsed=16.1s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=8400000 elapsed=16.5s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=8600000 elapsed=16.8s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=8800000 elapsed=17.2s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=9000000 elapsed=17.6s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=9200000 elapsed=18.0s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=9400000 elapsed=18.4s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=9600000 elapsed=18.8s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=9800000 elapsed=19.2s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=10000000 elapsed=19.6s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=10200000 elapsed=20.0s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=10400000 elapsed=20.4s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=10600000 elapsed=20.8s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=10800000 elapsed=21.2s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=11000000 elapsed=21.6s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=11200000 elapsed=22.0s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=11400000 elapsed=22.4s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=11600000 elapsed=22.7s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=11800000 elapsed=23.1s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=12000000 elapsed=23.5s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=12200000 elapsed=23.9s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=12400000 elapsed=24.3s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=12600000 elapsed=24.7s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=12800000 elapsed=25.1s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=13000000 elapsed=25.5s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=13200000 elapsed=25.9s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=13400000 elapsed=26.3s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=13600000 elapsed=26.7s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=13800000 elapsed=27.1s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=14000000 elapsed=27.4s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=14200000 elapsed=27.8s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=14400000 elapsed=28.2s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=14600000 elapsed=28.6s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=14800000 elapsed=29.0s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=15000000 elapsed=29.4s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=15200000 elapsed=29.8s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=15400000 elapsed=30.2s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=15600000 elapsed=30.6s bestZeros=23 bestHashDisplay=0000010fb36166ec59f8f84c...
# tries=15800000 elapsed=31.0s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=16000000 elapsed=31.3s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=16200000 elapsed=31.7s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=16400000 elapsed=32.1s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=16600000 elapsed=32.5s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=16800000 elapsed=32.9s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=17000000 elapsed=33.3s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=17200000 elapsed=33.6s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=17400000 elapsed=34.0s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=17600000 elapsed=34.4s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=17800000 elapsed=34.8s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=18000000 elapsed=35.2s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=18200000 elapsed=35.6s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=18400000 elapsed=36.0s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=18600000 elapsed=36.3s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=18800000 elapsed=36.7s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=19000000 elapsed=37.1s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=19200000 elapsed=37.5s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=19400000 elapsed=37.9s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=19600000 elapsed=38.3s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=19800000 elapsed=38.7s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=20000000 elapsed=39.1s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=20200000 elapsed=39.4s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=20400000 elapsed=39.8s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=20600000 elapsed=40.2s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=20800000 elapsed=40.6s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=21000000 elapsed=41.0s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=21200000 elapsed=41.4s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=21400000 elapsed=41.8s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=21600000 elapsed=42.2s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=21800000 elapsed=42.6s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=22000000 elapsed=42.9s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=22200000 elapsed=43.3s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=22400000 elapsed=43.7s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=22600000 elapsed=44.1s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=22800000 elapsed=44.5s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=23000000 elapsed=44.9s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=23200000 elapsed=45.3s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=23400000 elapsed=45.6s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=23600000 elapsed=46.0s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=23800000 elapsed=46.4s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=24000000 elapsed=46.8s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=24200000 elapsed=47.2s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=24400000 elapsed=47.6s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=24600000 elapsed=48.0s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=24800000 elapsed=48.4s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=25000000 elapsed=48.7s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=25200000 elapsed=49.1s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=25400000 elapsed=49.5s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=25600000 elapsed=49.9s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=25800000 elapsed=50.3s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=26000000 elapsed=50.7s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=26200000 elapsed=51.0s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=26400000 elapsed=51.4s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=26600000 elapsed=51.8s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=26800000 elapsed=52.2s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=27000000 elapsed=52.6s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=27200000 elapsed=53.0s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=27400000 elapsed=53.4s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=27600000 elapsed=53.8s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=27800000 elapsed=54.1s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=28000000 elapsed=54.5s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=28200000 elapsed=54.9s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=28400000 elapsed=55.3s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=28600000 elapsed=55.7s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=28800000 elapsed=56.1s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=29000000 elapsed=56.4s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=29200000 elapsed=56.8s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=29400000 elapsed=57.2s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=29600000 elapsed=57.6s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=29800000 elapsed=58.0s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=30000000 elapsed=58.4s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=30200000 elapsed=58.8s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=30400000 elapsed=59.2s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=30600000 elapsed=59.6s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=30800000 elapsed=59.9s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=31000000 elapsed=60.3s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=31200000 elapsed=60.7s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=31400000 elapsed=61.1s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=31600000 elapsed=61.5s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=31800000 elapsed=61.9s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=32000000 elapsed=62.3s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=32200000 elapsed=62.7s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=32400000 elapsed=63.1s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=32600000 elapsed=63.4s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=32800000 elapsed=63.8s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=33000000 elapsed=64.2s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=33200000 elapsed=64.6s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=33400000 elapsed=65.0s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=33600000 elapsed=65.4s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=33800000 elapsed=65.8s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=34000000 elapsed=66.1s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=34200000 elapsed=66.5s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=34400000 elapsed=66.9s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=34600000 elapsed=67.3s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=34800000 elapsed=67.7s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=35000000 elapsed=68.1s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=35200000 elapsed=68.5s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=35400000 elapsed=68.9s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=35600000 elapsed=69.3s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=35800000 elapsed=69.6s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=36000000 elapsed=70.0s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=36200000 elapsed=70.4s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=36400000 elapsed=70.8s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=36600000 elapsed=71.2s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=36800000 elapsed=71.6s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=37000000 elapsed=72.0s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=37200000 elapsed=72.4s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=37400000 elapsed=72.8s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=37600000 elapsed=73.1s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=37800000 elapsed=73.5s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=38000000 elapsed=73.9s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=38200000 elapsed=74.3s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=38400000 elapsed=74.7s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=38600000 elapsed=75.1s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=38800000 elapsed=75.5s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=39000000 elapsed=75.8s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=39200000 elapsed=76.2s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=39400000 elapsed=76.6s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=39600000 elapsed=77.0s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=39800000 elapsed=77.4s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=40000000 elapsed=77.8s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=40200000 elapsed=78.1s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=40400000 elapsed=78.5s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=40600000 elapsed=78.9s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=40800000 elapsed=79.3s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=41000000 elapsed=79.7s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=41200000 elapsed=80.1s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=41400000 elapsed=80.4s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=41600000 elapsed=80.8s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=41800000 elapsed=81.2s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=42000000 elapsed=81.6s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=42200000 elapsed=82.0s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=42400000 elapsed=82.4s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=42600000 elapsed=82.8s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=42800000 elapsed=83.1s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=43000000 elapsed=83.5s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=43200000 elapsed=83.9s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=43400000 elapsed=84.3s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=43600000 elapsed=84.7s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=43800000 elapsed=85.1s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=44000000 elapsed=85.5s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=44200000 elapsed=85.8s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=44400000 elapsed=86.2s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=44600000 elapsed=86.6s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=44800000 elapsed=87.0s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=45000000 elapsed=87.4s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=45200000 elapsed=87.7s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=45400000 elapsed=88.1s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=45600000 elapsed=88.5s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=45800000 elapsed=88.9s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=46000000 elapsed=89.3s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=46200000 elapsed=89.6s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=46400000 elapsed=90.0s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=46600000 elapsed=90.4s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=46800000 elapsed=90.8s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=47000000 elapsed=91.2s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=47200000 elapsed=91.6s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=47400000 elapsed=92.0s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=47600000 elapsed=92.3s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=47800000 elapsed=92.7s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=48000000 elapsed=93.1s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=48200000 elapsed=93.5s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=48400000 elapsed=93.9s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=48600000 elapsed=94.3s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=48800000 elapsed=94.7s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=49000000 elapsed=95.0s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=49200000 elapsed=95.4s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=49400000 elapsed=95.8s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=49600000 elapsed=96.2s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=49800000 elapsed=96.6s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=50000000 elapsed=97.0s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=50200000 elapsed=97.3s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=50400000 elapsed=97.7s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=50600000 elapsed=98.1s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=50800000 elapsed=98.5s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=51000000 elapsed=98.9s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=51200000 elapsed=99.2s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=51400000 elapsed=99.6s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=51600000 elapsed=100.0s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=51800000 elapsed=100.4s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=52000000 elapsed=100.7s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=52200000 elapsed=101.1s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=52400000 elapsed=101.5s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=52600000 elapsed=101.9s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=52800000 elapsed=102.3s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=53000000 elapsed=102.7s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=53200000 elapsed=103.0s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=53400000 elapsed=103.4s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=53600000 elapsed=103.8s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=53800000 elapsed=104.2s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=54000000 elapsed=104.6s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=54200000 elapsed=105.0s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=54400000 elapsed=105.4s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=54600000 elapsed=105.7s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=54800000 elapsed=106.1s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=55000000 elapsed=106.5s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=55200000 elapsed=106.9s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=55400000 elapsed=107.3s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=55600000 elapsed=107.6s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=55800000 elapsed=108.0s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=56000000 elapsed=108.4s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=56200000 elapsed=108.8s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=56400000 elapsed=109.1s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=56600000 elapsed=109.5s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=56800000 elapsed=109.9s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=57000000 elapsed=110.3s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=57200000 elapsed=110.7s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=57400000 elapsed=111.1s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=57600000 elapsed=111.4s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=57800000 elapsed=111.8s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=58000000 elapsed=112.2s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=58200000 elapsed=112.6s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=58400000 elapsed=113.0s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=58600000 elapsed=113.4s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=58800000 elapsed=113.8s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=59000000 elapsed=114.2s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=59200000 elapsed=114.6s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=59400000 elapsed=114.9s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=59600000 elapsed=115.3s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=59800000 elapsed=115.7s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=60000000 elapsed=116.1s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=60200000 elapsed=116.5s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=60400000 elapsed=116.9s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=60600000 elapsed=117.3s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=60800000 elapsed=117.7s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=61000000 elapsed=118.1s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=61200000 elapsed=118.4s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=61400000 elapsed=118.8s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=61600000 elapsed=119.2s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=61800000 elapsed=119.6s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=62000000 elapsed=120.0s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=62200000 elapsed=120.4s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=62400000 elapsed=120.8s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=62600000 elapsed=121.1s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=62800000 elapsed=121.5s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=63000000 elapsed=121.9s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=63200000 elapsed=122.3s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=63400000 elapsed=122.7s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=63600000 elapsed=123.1s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=63800000 elapsed=123.5s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=64000000 elapsed=123.9s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=64200000 elapsed=124.2s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=64400000 elapsed=124.6s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=64600000 elapsed=125.0s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=64800000 elapsed=125.4s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=65000000 elapsed=125.8s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=65200000 elapsed=126.1s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=65400000 elapsed=126.5s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=65600000 elapsed=126.9s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=65800000 elapsed=127.3s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=66000000 elapsed=127.7s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=66200000 elapsed=128.1s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=66400000 elapsed=128.5s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=66600000 elapsed=128.9s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=66800000 elapsed=129.2s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=67000000 elapsed=129.6s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=67200000 elapsed=130.0s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=67400000 elapsed=130.4s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=67600000 elapsed=130.8s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=67800000 elapsed=131.2s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=68000000 elapsed=131.6s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=68200000 elapsed=131.9s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=68400000 elapsed=132.3s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=68600000 elapsed=132.7s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=68800000 elapsed=133.1s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=69000000 elapsed=133.5s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=69200000 elapsed=133.9s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=69400000 elapsed=134.3s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=69600000 elapsed=134.7s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=69800000 elapsed=135.1s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=70000000 elapsed=135.4s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=70200000 elapsed=135.8s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=70400000 elapsed=136.2s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=70600000 elapsed=136.6s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=70800000 elapsed=137.0s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=71000000 elapsed=137.4s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=71200000 elapsed=137.8s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=71400000 elapsed=138.2s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=71600000 elapsed=138.6s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=71800000 elapsed=138.9s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=72000000 elapsed=139.3s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=72200000 elapsed=139.7s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=72400000 elapsed=140.1s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=72600000 elapsed=140.5s bestZeros=24 bestHashDisplay=000000db47ed113bbb0b5cf4...
# tries=72800000 elapsed=140.9s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=73000000 elapsed=141.2s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=73200000 elapsed=141.6s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=73400000 elapsed=142.0s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=73600000 elapsed=142.4s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=73800000 elapsed=142.8s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=74000000 elapsed=143.2s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=74200000 elapsed=143.6s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=74400000 elapsed=143.9s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=74600000 elapsed=144.3s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=74800000 elapsed=144.7s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=75000000 elapsed=145.1s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=75200000 elapsed=145.5s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=75400000 elapsed=145.9s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=75600000 elapsed=146.3s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=75800000 elapsed=146.7s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=76000000 elapsed=147.0s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=76200000 elapsed=147.4s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=76400000 elapsed=147.8s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=76600000 elapsed=148.2s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=76800000 elapsed=148.6s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=77000000 elapsed=149.0s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=77200000 elapsed=149.4s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=77400000 elapsed=149.7s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=77600000 elapsed=150.1s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=77800000 elapsed=150.5s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=78000000 elapsed=150.9s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=78200000 elapsed=151.3s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=78400000 elapsed=151.6s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=78600000 elapsed=152.0s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=78800000 elapsed=152.4s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=79000000 elapsed=152.8s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=79200000 elapsed=153.2s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=79400000 elapsed=153.6s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=79600000 elapsed=154.0s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=79800000 elapsed=154.3s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=80000000 elapsed=154.7s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=80200000 elapsed=155.1s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=80400000 elapsed=155.5s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=80600000 elapsed=155.9s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=80800000 elapsed=156.3s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=81000000 elapsed=156.7s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=81200000 elapsed=157.1s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=81400000 elapsed=157.5s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=81600000 elapsed=157.8s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=81800000 elapsed=158.2s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=82000000 elapsed=158.6s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=82200000 elapsed=159.0s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=82400000 elapsed=159.4s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=82600000 elapsed=159.7s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=82800000 elapsed=160.1s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=83000000 elapsed=160.5s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=83200000 elapsed=160.9s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=83400000 elapsed=161.3s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=83600000 elapsed=161.7s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=83800000 elapsed=162.1s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=84000000 elapsed=162.5s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=84200000 elapsed=162.8s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=84400000 elapsed=163.2s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=84600000 elapsed=163.6s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=84800000 elapsed=164.0s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=85000000 elapsed=164.4s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=85200000 elapsed=164.7s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=85400000 elapsed=165.1s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=85600000 elapsed=165.5s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=85800000 elapsed=165.9s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=86000000 elapsed=166.3s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=86200000 elapsed=166.7s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=86400000 elapsed=167.1s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=86600000 elapsed=167.5s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=86800000 elapsed=167.8s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=87000000 elapsed=168.2s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=87200000 elapsed=168.6s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=87400000 elapsed=168.9s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=87600000 elapsed=169.3s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=87800000 elapsed=169.7s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=88000000 elapsed=170.1s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=88200000 elapsed=170.5s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=88400000 elapsed=170.9s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=88600000 elapsed=171.3s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=88800000 elapsed=171.6s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=89000000 elapsed=172.0s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=89200000 elapsed=172.4s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=89400000 elapsed=172.8s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=89600000 elapsed=173.2s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=89800000 elapsed=173.6s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=90000000 elapsed=174.0s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=90200000 elapsed=174.3s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=90400000 elapsed=174.7s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=90600000 elapsed=175.1s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=90800000 elapsed=175.5s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=91000000 elapsed=175.9s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=91200000 elapsed=176.2s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=91400000 elapsed=176.6s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=91600000 elapsed=177.0s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=91800000 elapsed=177.4s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=92000000 elapsed=177.8s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=92200000 elapsed=178.2s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=92400000 elapsed=178.6s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=92600000 elapsed=178.9s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=92800000 elapsed=179.3s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=93000000 elapsed=179.7s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=93200000 elapsed=180.1s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=93400000 elapsed=180.5s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=93600000 elapsed=180.8s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=93800000 elapsed=181.2s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=94000000 elapsed=181.6s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=94200000 elapsed=182.0s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=94400000 elapsed=182.4s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=94600000 elapsed=182.8s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=94800000 elapsed=183.2s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=95000000 elapsed=183.6s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=95200000 elapsed=183.9s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=95400000 elapsed=184.3s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=95600000 elapsed=184.7s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=95800000 elapsed=185.1s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=96000000 elapsed=185.5s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=96200000 elapsed=185.9s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=96400000 elapsed=186.3s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=96600000 elapsed=186.7s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=96800000 elapsed=187.0s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=97000000 elapsed=187.4s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=97200000 elapsed=187.8s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=97400000 elapsed=188.2s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=97600000 elapsed=188.6s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=97800000 elapsed=189.0s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=98000000 elapsed=189.3s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=98200000 elapsed=189.7s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=98400000 elapsed=190.1s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=98600000 elapsed=190.5s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=98800000 elapsed=190.9s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=99000000 elapsed=191.3s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=99200000 elapsed=191.7s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=99400000 elapsed=192.0s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=99600000 elapsed=192.4s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=99800000 elapsed=192.8s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=100000000 elapsed=193.2s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=100200000 elapsed=193.6s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=100400000 elapsed=194.0s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=100600000 elapsed=194.4s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=100800000 elapsed=194.7s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=101000000 elapsed=195.1s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=101200000 elapsed=195.5s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=101400000 elapsed=195.9s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=101600000 elapsed=196.3s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=101800000 elapsed=196.7s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=102000000 elapsed=197.0s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=102200000 elapsed=197.4s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=102400000 elapsed=197.8s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=102600000 elapsed=198.2s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=102800000 elapsed=198.6s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=103000000 elapsed=199.0s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=103200000 elapsed=199.4s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=103400000 elapsed=199.8s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=103600000 elapsed=200.1s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=103800000 elapsed=200.5s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=104000000 elapsed=200.9s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=104200000 elapsed=201.3s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=104400000 elapsed=201.7s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=104600000 elapsed=202.0s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=104800000 elapsed=202.4s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=105000000 elapsed=202.8s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=105200000 elapsed=203.2s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=105400000 elapsed=203.6s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=105600000 elapsed=203.9s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=105800000 elapsed=204.3s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=106000000 elapsed=204.7s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=106200000 elapsed=205.1s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=106400000 elapsed=205.5s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# tries=106600000 elapsed=205.9s bestZeros=27 bestHashDisplay=00000016164dad33f90f996f...
# ...
# tries=227800000 elapsed=438.7s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=228000000 elapsed=439.1s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=228200000 elapsed=439.4s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=228400000 elapsed=439.8s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=228600000 elapsed=440.2s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=228800000 elapsed=440.6s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=229000000 elapsed=440.9s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=229200000 elapsed=441.3s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=229400000 elapsed=441.7s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=229600000 elapsed=442.1s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=229800000 elapsed=442.4s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=230000000 elapsed=442.8s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=230200000 elapsed=443.2s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=230400000 elapsed=443.6s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=230600000 elapsed=444.0s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=230800000 elapsed=444.3s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=231000000 elapsed=444.7s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=231200000 elapsed=445.1s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=231400000 elapsed=445.5s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=231600000 elapsed=445.8s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=231800000 elapsed=446.2s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=232000000 elapsed=446.6s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=232200000 elapsed=446.9s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=232400000 elapsed=447.3s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=232600000 elapsed=447.7s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=232800000 elapsed=448.1s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=233000000 elapsed=448.5s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=233200000 elapsed=448.8s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=233400000 elapsed=449.2s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=233600000 elapsed=449.6s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=233800000 elapsed=450.0s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=234000000 elapsed=450.3s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=234200000 elapsed=450.7s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=234400000 elapsed=451.1s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=234600000 elapsed=451.5s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=234800000 elapsed=451.9s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=235000000 elapsed=452.2s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=235200000 elapsed=452.6s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=235400000 elapsed=453.0s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=235600000 elapsed=453.4s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=235800000 elapsed=453.7s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=236000000 elapsed=454.1s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=236200000 elapsed=454.5s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=236400000 elapsed=454.9s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=236600000 elapsed=455.3s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=236800000 elapsed=455.6s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=237000000 elapsed=456.0s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=237200000 elapsed=456.4s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=237400000 elapsed=456.7s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=237600000 elapsed=457.1s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=237800000 elapsed=457.5s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=238000000 elapsed=457.9s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=238200000 elapsed=458.3s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=238400000 elapsed=458.6s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=238600000 elapsed=459.0s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=238800000 elapsed=459.4s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=239000000 elapsed=459.8s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=239200000 elapsed=460.2s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=239400000 elapsed=460.5s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=239600000 elapsed=460.9s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=239800000 elapsed=461.3s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=240000000 elapsed=461.7s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=240200000 elapsed=462.1s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=240400000 elapsed=462.5s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=240600000 elapsed=462.8s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=240800000 elapsed=463.2s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=241000000 elapsed=463.6s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=241200000 elapsed=464.0s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=241400000 elapsed=464.3s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=241600000 elapsed=464.7s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=241800000 elapsed=465.1s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=242000000 elapsed=465.5s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=242200000 elapsed=465.8s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=242400000 elapsed=466.2s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=242600000 elapsed=466.6s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=242800000 elapsed=467.0s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=243000000 elapsed=467.3s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=243200000 elapsed=467.7s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=243400000 elapsed=468.1s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=243600000 elapsed=468.5s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=243800000 elapsed=468.8s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=244000000 elapsed=469.2s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=244200000 elapsed=469.6s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=244400000 elapsed=470.0s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=244600000 elapsed=470.3s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=244800000 elapsed=470.7s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=245000000 elapsed=471.1s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=245200000 elapsed=471.5s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=245400000 elapsed=471.8s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=245600000 elapsed=472.2s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=245800000 elapsed=472.6s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=246000000 elapsed=473.0s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=246200000 elapsed=473.4s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=246400000 elapsed=473.7s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=246600000 elapsed=474.1s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=246800000 elapsed=474.5s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=247000000 elapsed=474.9s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=247200000 elapsed=475.3s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=247400000 elapsed=475.6s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=247600000 elapsed=476.0s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=247800000 elapsed=476.4s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=248000000 elapsed=476.8s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=248200000 elapsed=477.1s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=248400000 elapsed=477.5s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=248600000 elapsed=477.9s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=248800000 elapsed=478.3s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=249000000 elapsed=478.6s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=249200000 elapsed=479.0s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=249400000 elapsed=479.4s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=249600000 elapsed=479.8s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=249800000 elapsed=480.1s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=250000000 elapsed=480.5s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=250200000 elapsed=480.9s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=250400000 elapsed=481.3s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=250600000 elapsed=481.7s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=250800000 elapsed=482.0s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=251000000 elapsed=482.4s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=251200000 elapsed=482.8s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=251400000 elapsed=483.2s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=251600000 elapsed=483.5s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=251800000 elapsed=483.9s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=252000000 elapsed=484.3s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=252200000 elapsed=484.7s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=252400000 elapsed=485.1s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=252600000 elapsed=485.5s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=252800000 elapsed=485.8s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=253000000 elapsed=486.2s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=253200000 elapsed=486.6s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=253400000 elapsed=487.0s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=253600000 elapsed=487.4s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=253800000 elapsed=487.8s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=254000000 elapsed=488.2s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=254200000 elapsed=488.6s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=254400000 elapsed=488.9s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=254600000 elapsed=489.3s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=254800000 elapsed=489.7s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=255000000 elapsed=490.1s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=255200000 elapsed=490.5s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=255400000 elapsed=490.8s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=255600000 elapsed=491.2s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=255800000 elapsed=491.6s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=256000000 elapsed=492.0s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=256200000 elapsed=492.4s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=256400000 elapsed=492.8s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=256600000 elapsed=493.1s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=256800000 elapsed=493.5s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=257000000 elapsed=493.9s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=257200000 elapsed=494.3s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=257400000 elapsed=494.7s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=257600000 elapsed=495.0s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=257800000 elapsed=495.4s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=258000000 elapsed=495.8s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=258200000 elapsed=496.2s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=258400000 elapsed=496.6s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=258600000 elapsed=497.0s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=258800000 elapsed=497.4s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=259000000 elapsed=497.7s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=259200000 elapsed=498.1s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=259400000 elapsed=498.5s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=259600000 elapsed=498.9s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=259800000 elapsed=499.3s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=260000000 elapsed=499.6s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
# tries=260200000 elapsed=500.0s bestZeros=31 bestHashDisplay=00000001aeca65dd67322732...
#
# ⏱️ Tiempo límite alcanzado.
# Mejor hasta ahora:
# bestZeros: 31
# bestHeader80: 0d5452657c5f22e0d240f335aaf33db322a1a72431770f37d31b9f42420c2a09d49c87327e4098a86b77e4b999ce5f0b7e0cf488e80dc2b0361bacddf650efdd80716c18817295a29164e864e0abe161
# bestHash display: 00000001aeca65dd67322732841fca41667cfaa40e8b0febad5817c7a06e0eb8
#
# ⚠️ No encontrado en este tiempo. Sube max_seconds o baja dificultad.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-890336629.py in <cell line: 0>()
#     598
#     599 while True:
# --> 600     bits_hex = input("\nBITS compact (8 hex) o 'q': ").strip()
#     601     if bits_hex.lower() == 'q':
#     602         break
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
